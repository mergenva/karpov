# %% [markdown]
# # Практика 3: Пользовательские функции

# %% [markdown]
# Пользовательские функции — одни из ключевых элементов программирования на языке Python. Они позволяют разработчикам создавать модульные и переиспользуемые блоки кода, которые могут быть вызваны в различных частях программы. Это значительно упрощает процесс разработки, делает код более структурированным, читаемым и понятным.

# %% [markdown]
# **Инструкция по выполнению заданий:**
#
# Для решения заданий в данном блоке вам необходимо выполнить следующие шаги:
#
# - Скачайте архив с материалами урока по ссылке
# - Загрузите Jupyter ноутбук в свою папку в юпитерхабе или откройте его на своем компьютере
# - Следуйте по шагам, описанным в Jupyter ноутбуке
# - Копируйте код из Jupyter ноутбука и сдавайте его на проверку в LMS
#
#
# Вы можете решать задания тем способом, который считаете наиболее удобным или оптимальным. А для того, чтобы лучше понять задание, следуйте по шагам выполнения. Бывает, что их можно выполнить в одну строчку, применяя методы друг за другом. А если выполняете шаги отдельно, не забудьте сохранить результат в переменную, чтобы в следующем шаге работать именно с ней.
#
# В этом ноутбуке место для вашего решения обозначено комментарием `# Ваш код здесь`, но вы можете писать код где вам удобно, добавлять или удалять ячейки с кодом или текстом по вашему усмотрению.
#
# Напоминаем о конспектах и ноутбуке с лекцией! Всё необходимое для решения задач, описанно там, поэтому рекомендуем открыть их в отдельном окне и периодически сверяться с материалом.
#
# Кроме того, можно посмотреть подсказки, кликнув на строчку `► Нажмите сюда, чтобы увидеть подсказку`.
#
# Также не забывайте и о возможности задать вопрос в Discord, ссылка на нужный тред есть на странице каждого шага в LMS.
#
# Желаем успехов!

# %% [markdown]
# **Примечание:**
#
# В LMS в некоторых заданиях для проверки работоспособности функций будут использоваться различные наборы тестовых данных, а не только значения, указанные в условии.
#
# Это поможет убедиться, что ваша функция универсальна и работает правильно не только на конкретных примерах, которые указаны в заданиях, но и на более широком наборе тестовых данных. Также благодаря этому можно выявить возможные ошибки и неточности в написании кода.
#
# Кроме того, в каждой задаче после фразы `Раскомментировать и проверить работу функции` приведён код, с помощью которого вы можете сами проверить вашу функцию: можете изменять входные данные и тестировать разные варианты.
#
# Также обратите внимание, что в решении задач имена аргументов в ваших функциях могут быть любыми. Главное, чтобы функция работала и возвращала/печатала правильный результат. Поэтому в некоторых задачах в качестве примеров приводятся входные значения в общем виде без указания имён переменных.
#
# **ВАЖНО!** Аргументы, которые будут использоваться внутри функции, необходимо передавать в той последовательности, в которой они прописаны в задаче. Это необходимо для корректной оценки кода проверяющей системой.

# %% [markdown]
# ### Задание 1.

# %% [markdown]
# Выходные прошли, а значит, пора вернуться к практике Python и с новыми силами продолжить стажировку в karpov.courses!
#
# Добравшись в понедельник до рабочего места и открыв свой ноутбук, вы обратили внимание, что он вас никак не приветствует. Это нужно срочно исправить!
#
# Чтобы начинать рабочий день было приятнее, вы решили написать небольшую функцию, которая будет в качестве аргумента принимать **ваше имя** и печатать приветствие.
#
# Задайте функцию `hello`, которая будет принимать один аргумент (имя пользователя) и печатать сообщение в следующем формате:
#
# ``Привет, <имя пользователя>!``
#
# **Пример:**
#
# Если на вход в функцию подаётся имя `Анатолий`, должна печататься следующая строка:
#
# ``Привет, Анатолий!``
#
# Тело функции должно содержать только код для вывода сообщения. Аргумент функции можете назвать как угодно — например, `name`.
#
# **Важно!** В этой задаче и далее вносите в ЛМС только определение функции. Код с проверкой работы функции в ответ включать не нужно.
#
# Обратите внимание, что код  необходимо писать в Jupyter ноутбуке, и только потом, проверив его работоспособность, переносить в LMS.
#
# Не стоит сдавать в LMS код, который не работает или выдает некорректный результат в Jupyter ноутбуке, поскольку ошибка также сохранится и в проверяющей системе.

# %% [markdown]
# <details>
# <summary>&#9658; Нажмите сюда, чтобы увидеть подсказку</summary>
#   <p>
#
# Для решения задачи напишите функцию с названием `hello`, принимающую один аргумент (имя пользователя) и печатающую сообщение с помощью функции `print()`:
#
# Образец функции:
#
# ```python
#
# def function_name(arg1):
#     print(сообщение)
# ```
#
# Чтобы вывести приветственное сообщение с использованием значения аргумента, используйте `f-строки`.
#
# Для создания `f-строки` необходимо перед строкой поставить префикс `"f"` или `"F"`, а затем внутри строки использовать фигурные скобки `{}` для вставки переменных или выражений:
#
# ```python
#
# f"Привет, {название_переменной}!"
# ```
#
# </p>
# </details>

# %%
# Ваш код здесь
def hello(name):
    print(f'Привет, {name}!')

hello('Mergen')

# %% [markdown]
# ### Задание 2.

# %% [markdown]
# Сегодня до рабочего места вы добрались раньше всех. И пока коллег нет, вы задумались над важным вопросом: сколько дней осталось до конца вашей стажировки?
#
# Вы точно помните, что договорились о стажировке длительностью 12 недель. Пока с учётом выходных прошло всего 3 дня, а значит, до конца остался ещё 81 день. Но на собеседовании вам говорили, что при необходимости стажировку могут продлить или, наоборот, сократить. Кажется, здесь начинается уже какая-то сложная математика. Поэтому, чтобы считать дни было проще, вы решили написать небольшую функцию-калькулятор для расчёта числа дней, оставшихся до конца стажировки.
#
# Напишите функцию `calculate_days`, которая будет принимать два аргумента:
#
# * количество дней, которое вы уже отработали — `days_passed`
# * длительность стажировки в неделях — `weeks_total`
#
# Поскольку вас взяли на стажировку, которая будет длиться 12 недель, второй аргумент должен иметь значение по умолчанию, равное 12.
#
# Сама функция должна производить необходимые расчёты и возвращать количество дней, оставшихся до конца стажировки.
#
# Теперь вы всегда будете точно знать, сколько дней осталось практиковаться. Если, конечно, будете помнить, сколько дней уже прошло.
#
# **Пример:**
#
# Например, вы уже отработали 22 дня, но вдруг узнали, что стажировку продлили на 1 неделю (`weeks_total=13`). Тогда до конца стажировки останется 69 дней.
#
# **Примечание:**
#
# В задаче считаем, что выходные тоже входят в период стажировки. Также обратите внимание, что функция должна именно возвращать значение и при этом не должна ничего печатать.

# %% [markdown]
# <details>
# <summary>&#9658; Нажмите сюда, чтобы увидеть подсказку</summary>
#   <p>
#
# Для решения задачи напишите функцию с названием `calculate_days`. Функция должна принимать два аргумента  (`days_passed` и `weeks_total`) и считать, сколько дней осталось до конца стажировки:
#
#
# Образец функции:
# ```python
#
# def function_name(arg1, arg2=default_value2):
#     код
#     return результат
# ```
# Обратите внимание, что второй аргумент должен иметь значение по умолчанию (`weeks_total=12`).
#
# Как посчитать количество дней, оставшихся до конца стажировки:
#
# * Сначала узнайте общее количество дней стажировки, умножив количество недель `weeks_total` на количество дней в неделе (`7`).
#
# * Затем вычислите число оставшихся дней, отняв от общего количества дней количество прошедших дней (`days_passed`).
#
# </p>
# </details>

# %%
# Ваш код здесь

def calculate_days(days_passed, weeks_total=12):
    days_total = weeks_total * 7
    return f"Осталось работать на испытательном сроке - {days_total - days_passed}"

calculate_days(12, 14)

# %% [markdown]
# ### Задание 3.

# %% [markdown]
# Как только вы закончили работу над функцией-калькулятором, раздался звук сообщения в Telegram: «Стою в пробке, опаздываю. Вот несколько задач на сегодня. Присылай код по готовности, всё посмотрю».
#
# А вот и новые задачи. Однако в этот раз Анатолий Карпов передал их не в виде списка, а в текстовом файле `tasks.txt`. Значит, чтобы посмотреть, что вас ожидает сегодня, нужно этот файл как-то прочитать.
#
# Прочитайте файл с названием `tasks.txt` с помощью контекстного менеджера `with` и функции `open()` и построчно распечатайте задачи. Для этого передайте в функцию `open()` переменную `file_name`, в которой уже содержится название файла.
#
# В функцию `open()`, помимо переменной с названием файла, также передайте аргумент `encoding='utf-8'`, чтобы данные были прочитаны в правильной кодировке.
#
# В файле `tasks.txt` каждой строке соответствует одна задача. Перед выводом задач на печать не забудьте избавиться от знаков переноса строки (`\n`).
#
# **Пример:**
#
# Если файл с задачами содержит три строки с задачами, то вывод будет выглядеть, например, так:
# ```
# Задача 1. Открыть файл с задачами
# Задача 2. Ознакомиться с задачами
# Задача 3. Выполнить задачи
# ```
#
# **Примечание:**
#
# Чтобы прочитать текстовый файл `tasks.txt`, предварительно скачайте его **по ссылке** и загрузите в свою папку на Jupyter-хабе, где находится данный ноутбук. Если вы работаете с данным ноутбуком локально на своём компьютере, не забудьте положить текстовый файл в папку с ноутбуком.
#
# Свою функцию в этой задаче писать не нужно.

# %% [markdown]
# Переменная `file_name` с названием файла уже создана:

# %%
file_name = 'tasks.txt'

# %% [markdown]
# <details>
# <summary>&#9658; Нажмите сюда, чтобы увидеть подсказку</summary>
#   <p>
#
# Чтобы прочитать файл и построчно распечатать задачи, используйте контекстный менеджер `with`, функцию `open()` и функцию `print()`:
#
# ```python
# # Передаем путь
# with open('file.txt') as f:
#     print(f.read())
# ```
#
# Также можно воспользоваться следующей конструкцией:
# ```python
# with open('file.txt') as f:
#     for line in f:
#         print(line.strip())
# ```
# Однако в таком случае необходимо избавиться от знаков переноса (`\n`) с помощью функции `strip()`.
#
# Не забудьте в функцию `open()` дополнительным параметром передать `encoding='utf-8'`:
# ```python
# with open('file.txt', encoding='utf-8') as f:
#     ...
# ```
#
#
# </p>
# </details>

# %%
# Ваш код здесь
with open(file_name, encoding='utf-8') as f:
    for line in f:
        print(line)

# %% [markdown]
# ### Задание 4.

# %% [markdown]
# Прочитав текстовый документ, вы задумались: а что если руководитель теперь всегда будет присылать задачи в текстовом файле?
#
# Тогда каждый раз копировать код будет неудобно, да и переменная с названием файла может меняться. К тому же, было бы неплохо заносить задачи в отдельный список.
#
# Поэтому вы решили сделать универсальную функцию, которая будет считывать любой передаваемый ей файл и записывать задачи в список.
#
# Напишите функцию `read_tasks`, которая будет принимать один аргумент — **название файла**.
#
# Функция должна считывать передаваемый файл с кодировкой `encoding='utf-8'`, убирать знаки переноса строки (`\n`), записывать задачи в список и возвращать его.
#
# Для считывания файла в теле функции `read_tasks` должна вызываться функция `open()`, в которую в качестве названия файла будет передаваться аргумент функции `read_tasks`.
#
# **Примечание:**
#
# Обратите внимание, что в этой задаче функция не должна ничего печатать. Она должна считывать файл и возвращать список с задачами.

# %% [markdown]
# <details>
# <summary>&#9658; Нажмите сюда, чтобы увидеть подсказку</summary>
#   <p>
#
# Что делать тут?
#
# Вам необходимо обернуть код с прочтением файла с прошлого шага в функцию `read_tasks`, которая будет принимать на вход один аргумент — название файла. Однако теперь необходимо сделать так, чтобы функция не печатала задачи, а складывала их в список и возвращала его.
#
# Функция должна вернуть список с преобразованными строками.
#
# Образец функции:
#
# ```python
# def название_функции(<название_файла>):
#     новый_список = []
#     with open(<название_файла>, encoding='utf-8') as f:
#         код, который считывает файл, очищает строки и добавляет их в новый_список
#     return новый_список
# ```
#
# Как добавить строки с задачами в список?
#
# Создайте пустой список, в который будут добавляться все задачи. Далее с помощью цикла `for` считайте каждую строку текстового документа, удалите в ней знаки переноса (`\n`) с помощью метода `strip()` и добавьте её в в новый список.
#
# Пример кода:
#
# ```python
# file_name = 'responses.txt'
# new_list = []
# # Открываем файл
# with open(file_name) as f:
#     # Идем итеративно по строкам
#     for line in f:
#         # Удаляем пробельные символы с концов
#         strip_line = line.strip()
#         # Добавляем очищенную строку в new_list
#         new_list.append(strip_line)
# ```
#
# </p>
# </details>

# %%
# Ваш код здесь

def read_tasks(file_name):
    with open(file_name, encoding='utf-8') as f:
        text = f.read()
        text = text.split('\n')
    return text

read_tasks('tasks.txt')

# %%
text = 'Задача , Задача'
text.count('Задача ')

# %% [markdown]
# ### Задание 5.

# %% [markdown]
# Уже выглядит неплохо. И самое главное — работает!
#
# Однако совершенству нет предела, и было бы вообще отлично, если бы после прочтения файла можно было сразу понять, как много работы сегодня предстоит выполнить. Для этого вы решили немного модифицировать уже написанную функцию.
#
# Напишите новую функцию `read_tasks_upd`, которая будет также принимать один аргумент — **название файла**.
#
# Функция по-прежнему должна считывать передаваемый файл с кодировкой `encoding='utf-8'`, убирать знаки переноса строки (`\n`), записывать задачи в список и возвращать его.
#
# Для считывания файла в теле функции `read_tasks` снова должна вызываться функция `open()`, в которую в качестве названия файла будет передаваться аргумент функции `read_tasks`.
#
# Дополнительно сделайте так, чтобы функция считала, сколько заданий содержится в файле, затем в зависимости от их числа выводила сообщение:
#
# * Если задач меньше 5, то функция должна печатать: `Сегодня задач немного.`
# * Если задач 5 и более, то необходимо вывести: `Сегодня много задач.`
# * Если задач 0, то функция должна выводить: `Сегодня задач нет. Можно отдыхать.`
#
# При этом если задачи есть, то функция также должна печатать на новой строке: `Задачи добавлены в список!`
#
# **Пример:**
#
# Если в файле оказалось 5 задач, то функция `read_tasks_upd` должна записать их в список, вернуть его и вывести следующее сообщение:
#
# ```
# Сегодня много задач.
# Задачи добавлены в список!
# ```
#
# **Примечание:**
#
# Обратите внимание, что в этой задаче функция должна и печатать сообщение, и возвращать список с задачами.

# %% [markdown]
# <details>
# <summary>&#9658; Нажмите сюда, чтобы увидеть подсказку</summary>
#   <p>
#
# Создайте функцию `read_tasks_upd`, которая будет модифицированной версией функции `read_tasks`.
#
# После добавления очищенных значений в новый список, вам неоходимо посчитать, сколько заданий содержится в текстовом документе.
#
# В очищенном списке каждый элемент представляет собой одно задание. Поэтому, чтобы узнать сколько заданий в текстовом документе, необходимо посчитать, сколько элементов в новом списке. В этом вам поможет функция `len()`.
#
# Не забудьте сохранить количество заданий в отдельную переменную.
#
# Далее, используя условные конструкции `if/else`, проверьте:
#
# * если задач 0, то выведите сообщение: ```Сегодня задач нет. Можно отдыхать.```
#
# Иначе добавьте ещё одну вложенную условную конструкцию `if/else` и проверьте:
#
# * если задач 5 и более, выведите сообщение: ```Сегодня много задач.```
# * иначе выведите сообщение: ```Сегодня задач немного.```
#
# Также в основной условной конструкции в блоке `else` выведите сообщение: ```Задачи добавлены в список!```
#
# Пример кода с вложенными условными конструкциями:
#
# ```python
# # Задаем переменную с возрастом пользователя
# age = 15
#
# # В основном блоке `if/else` проверяем, является ли пользователь совершеннолетним
# if age >= 18:
#     print("Совершеннолетний")
#     print("Есть паспорт")
# else:
#     # Во вложенной условной конструкции `if/else` проверяем, есть ли у пользователя паспорт
#     if age < 14:
#         print("Нет паспорта")
#     else:
#         print("Есть паспорт")
#     # Обратите внимание, эта часть с функцией print() относится к основному блоку `if/else`
#     print("Несовершеннолетний")
#
# # Результат
# Есть паспорт
# Несовершеннолетний
# ```
#
# Также не забудьте, что в конце функция должна вернуть список с преобразованными строками (задачами).
#
# </p>
# </details>

# %%
# Ваш код здесь
def read_tasks_upd(file_name):
    with open(file_name, encoding='utf-8') as f:
        text = f.read()
        tasks = text.split('\n')
        # второй способ counter = text.count('Задача')
        if len(tasks) >= 5:
            print('Сегодня много задач.')
            print('Задачи добавлены в список!')
        elif len(tasks) < 5:
            print('Сегодня задач немного.')
            print('Задачи добавлены в список!')
        else:
            print('Сегодня задач нет. Можно отдыхать.')
    return tasks

read_tasks_upd('tasks.txt')

# %% [markdown]
# ### Задание 6.

# %% [markdown]
# Теперь важный процесс автоматизирован, и в следующий раз чтение файла от руководителя не займёт много времени.
#
# А сейчас пора приступать к самим задачам. Кажется, в первый день стажировки вы показали отличные навыки работы с Python и поэтому вам доверили ответственное дело — посчитать продуктовую метрику! От отдела маркетинга поступили данные о количестве покупок курсов и числе переходов на сайт за определённый период. На основе этой информации необходимо посчитать конверсию.
#
# Немного покопавшись в документации, вы выяснили, что **конверсия (conversion rate, CR)** — это отношение числа пользователей, которые выполнили какое-то целевое действие, к общему числу пользователей.
#
# Судя по всему, в данном случае вам необходимо узнать конверсию в покупку, то есть понять, какая часть пользователей, посетивших сайт компании, совершила покупку.
#
# Формула для расчёта конверсии в покупку (в процентах) выглядит следующим образом:
#
# ```python
# Конверсия = (Количество пользователей, совершивших покупку / Общее количество пользователей) * 100
# ```
#
# Ну что же, вроде бы все данные у вас есть, можно приступать к расчётам. Немного поразмыслив, вы решили, что с такой задачей могут обратиться ещё не раз, поэтому лучше сразу написать функцию, которая будет считать конверсию по любым данным о покупках и переходах на сайт.
#
# Напишите функцию `calculate_cr`, которая будет принимать два аргумента: **количество покупок** и **количество посещений сайта**. Поскольку по правилам математики делить на 0 просто так нельзя, внутри функции необходимо проверить, что количество посещений не равно 0.
#
# Если количество посещений не равно 0, то функция должна посчитать конверсию и вывести сообщение:
#
# ```Конверсия в покупку: <значение конверсии>% ```
#
# Если количество посещений равно 0, то функция не должна ничего считать, а должна просто напечатать следующее сообщение:
#
# ```Количество переходов равно 0, невозможно рассчитать конверсию. ```
#
#
# Значение конверсии необходимо выразить в процентах и округлить до двух знаков после запятой.
#
#
# **Пример:**
#
# Если количество посещений сайта равно 1100, а количество покупок составляет 50, функция должна посчитать конверсию и напечатать следующее:
#
# `Конверсия в покупку: 4.55%`
#
# **Примечание:**
#
# Обратите внимание, что в этой задаче функция не должна возвращать само значение конверсии. Она должна печатать сообщение.

# %% [markdown]
# <details>
# <summary>&#9658; Нажмите сюда, чтобы увидеть подсказку</summary>
#   <p>
#
# Для решения задачи создайте функцию `calculate_cr`, которая:
#
# * принимает два аргумента: `purchases` (количество покупок) и `visits` (количество посещений)
#
# * с помощью условной конструкции `if/else` проверяет, равно ли 0 значение `visits`.
#
# Если значение `visits` равно 0, то с помощью функции `print()` функция выводит сообщение:
#
# ```Количество переходов равно 0, невозможно рассчитать конверсию.```
#
# Иначе производит расчет конверсии и с помощью функции `print()` и `f-строки` выводит сообщение:
#
# ```Конверсия в покупку: <значение конверсии>%```
#
# **Обратите внимание** на знаки препинания и знак `%` в конце предложения.
#
# А как расчитать нужную метрику и округлить результат до двух знаков после запятой?
#
# Чтобы расчитать процент конверсии в покупку, используйте формулу:
#
# ```python
# Процент конверсии = (Количество пользователей, совершивших покупку / Общее количество посетителей) * 100
# ```
# Для округления числа до определённого числа знаков после запятой в Python есть  фукнция `round()`.
# Она принимает два аргумента: число, которое нужно округлить, и количество знаков после запятой, до которого нужно округлить.
#
# Пример похожих вычислений:
#
# ```python
# total_tasks = 30
# completed_tasks = 19
# # Вычисляем процент выполненных задач и округляем до 3 знаков после запятой
# completion_rate = round((completed_tasks / total_tasks) * 100, 3)
# # Выводим результат при помощи функции print() и f-строк
# print(f"Округленный процент выполненных задач: {completion_rate}")
#
# # Результат
# Округленный процент выполненных задач: 63.333
# ```
#
#
# </p>
# </details>

# %%
# Ваш код здесь

def calculate_cr(quantity_purchases, quantity_visits):
    if quantity_visits > 0:
        CR = round(quantity_purchases / quantity_visits * 100,2)
        print(f'conversion rate, CR - {CR}')
    elif quantity_visits == 0:
        print('Количество переходов равно 0, невозможно рассчитать конверсию.')
    
    
calculate_cr(100,778)

# %% [markdown]
# ### Задание 7.

# %% [markdown]
# Вы отправили свой код на проверку руководителю и спустя несколько минут получили ответ. Решение оказалось верным, но выяснилось, что конверсию не всегда считают только по двум значениям. Иногда отдел маркетинга присылает сразу два списка со значениями числа переходов и числа покупок — например, когда требуется рассчитать конверсии отдельно по месяцам. И для этого потребуется ещё одна функция.
#
# Звучит логично! И похоже, что для решения этой задачи нам снова пригодятся циклы.
#
# Напишите ещё одну функцию с названием `calculate_cr_upd`, которая будет принимать на вход два аргумента — **список со значениями числа покупок** и **список со значениями числа переходов**. Оба списка всегда имеют равную длину и содержат хотя бы по одному элементу.
#
# Для каждой пары значений в списках функция должна посчитать значение конверсии и вернуть новый список с рассчитанными конверсиями. Как и в предыдущем задании, значения конверсий необходимо выразить в процентах и округлить до двух знаков после запятой.
#
# Законы математики по-прежнему имеют силу. Поэтому в случаях, когда число переходов равно `0`, необходимо в итоговый список вместо значения конверсии поместить значение `None`.
#
# **Пример:**
#
# Допустим, на вход функция получила следующие списки:
#
# ```python
# [10, 5, 8, 0, 0, 12]
# ```
#
# ```python
# [500, 650, 730, 0, 80, 320]
# ```
#
# Тогда результатом работы функции `calculate_cr_upd` будет список конверсий:
#
# ```python
# [2.0, 0.77, 1.1, None, 0.0, 3.75]
# ```
#
# **Примечание:**
#
# Обратите внимание, что в этой задаче функция не должна ничего печатать. Она должна возвращать список с конверсиями.

# %% [markdown]
# <details>
# <summary>&#9658; Нажмите сюда, чтобы увидеть подсказку</summary>
#   <p>
#
# Чтобы написать новую функцию для расчёта конверсии, можно немного переделать фукнцию `calculate_cr` из предыдущего задания.
#
# Для начала задайте функцию `calculate_cr_upd` с двумя аргументами — например, их можно назвать `purchases_list` и `visits_list`.
#
# Затем создайте в теле функции пустой список `conversion_rate_list`, в который будете добавлять посчитанные конверсии.
#
# Далее используйте цикл `for` с функцией `zip()` для одновременной итерации по значениям из списков `purchases_list` и `visits_list`.
#
# На каждой итерации с помощью условной конструкции `if/else` проверьте, равно ли значение числа посещений `0`:
#
# * Если да, то создайте переменную `conversion_rate` и присвойте ей значение `None`
# * Иначе поделите элементы списков и поместите в переменную `conversion_rate` значение конверсии в покупку, выраженное в процентах и округлённое до двух знаков после запятой.
#
# Округлить значение можно с помощью функции `round()`.
#
# Добавьте полученное значение `conversion_rate` в заранее созданный список `conversion_rate_list`. Вспомните, с помощью какого метода можно добавлять значения в список.
#
# В конце после цикла `for` верните значение `conversion_rate_list` при помощи оператора `return`.
#
# </p>
# </details>

# %%
# Ваш код здесь

def calculate_cr_upd(p, v):
    cr_list = []
    for p, v in zip(purchases, visits):
        if v != 0:
            cr = round(p / v * 100, 2)            
        else:
            cr = None
        cr_list.append(cr)
    return cr_list


purchases = [19, 9, 8, 0, 0, 19]
visits = [500, 650, 730, 0, 80, 320]
calculate_cr_upd(purchases, visits)

# %% [markdown]
# ### Задание 8.

# %% [markdown]
# Кажется, с конверсиями разобрались. На очереди что-то важное от отдела продаж.
#
# Руководитель отдела хочет контролировать, как часто перевыполняется план по продажам одного из новых продуктов компании. Для этого вас просят написать код, который будет сравнивать значения выручки по месяцам с плановым значением и считать число месяцев, в которых фактическое значение оказывается выше планового.
#
# Вам необходимо реализовать функцию `count_months`, которая будет принимать на вход два аргумента — **данные о выручке за определённый период** и **пороговое значение выручки**.
#
# Данные о выручке будут приходить в виде списка из кортежей следующего вида:
#
# ```python
# [
#     ('01.01', 100000),
#     ('01.02', 150000),
#     ('01.03', 250000),
#     ...
# ]
# ```
#
# В каждом кортеже сначала указывается наименование месяца (в формате «первое число + порядковый номер месяца»), а затем — суммарная выручка за этот месяц.
#
# При этом список с данными о выручке может быть любой размерности и всегда содержит хотя бы один элемент.
#
# Функция должна считать число месяцев, в которых выручка превышает пороговое значение, и печатать сообщение следующего формата:
#
# ```Количество месяцев с выручкой выше <пороговое значение>: <количество месяцев, в которых выручка превышает пороговое значение>```
#
# **Пример:**
#
# Допустим, на вход в функцию подаётся список с данными о выручке за 1-й квартал:
#
# ```python
# [
#     ('01.01', 100000),
#     ('01.02', 150000),
#     ('01.03', 250000)
# ]
# ```
#
# Также в качестве порогового значения подаётся значение `100000`.
#
# Тогда функция должна вывести следующее сообщение:
#
# `Количество месяцев с выручкой выше 100000: 2`
#
#
# **Примечание:**
#
# Обратите внимание, что в этой задаче функция не должна ничего возвращать. Она должна печатать сообщение.
#
# Для решения задания попробуйте использовать **`lambda-функцию`** и **`функцию map()`**.

# %% [markdown]
# <details>
# <summary>&#9658; Нажмите сюда, чтобы увидеть подсказку</summary>
#   <p>
#
# Объявите функцию `count_months`, которая будет принимать два аргумента: данные о выручке и пороговое значение.
#
# Используя функцию `map()` в паре с `lambda-функцией` для каждого значения выручки проверьте, превышает ли оно пороговое значение. Затем,  используя функцию `sum()`, посчитайте, сколько значений превышает порог.
#
# Пример использования функции `map()` с `lambda-функцией`:
#
# ```python
# # Создаем список чисел
# numbers = [1, 2, 3, 4, 5]
#
# # Используем функцию map с lambda-функцией для возведения каждого числа в квадрат и функцию sum для подсчета суммы всех квадратов чисел
# squared_numbers = sum(map(lambda x: x**2, numbers))
# print(squared_numbers)
#
# # Результат
# 55
# ```
#
# Обратите внимание, что мы имеем дело со списком из кортежей, поэтому на каждой итерации будем получать кортеж вида:
#
# ```(месяц, значение выручки)```
#
# К элементам кортежа можно обращаться по индексам. Значение выручки в кортеже всегда идёт вторым.
#
# **Не забывайте**, что индексация в Python начинается с 0!
#
# Выведите сообщение при помощи функции `print()` и `f-строк`:
#
# ```Количество месяцев с выручкой выше {пороговое значение}: {количество месяцев, в которых выручка превышает пороговое значение}```
#
#
# Данную задачу можно решить и без использования функции `map()` в паре с `lambda-функцией`.
#
# Для этого необходимо в теле функции создать переменную, которая будет использоваться в качестве счетчика для подсчета количества месяцев с выручкой выше порогового значения.
#
# С помощью цикла `for` пройдитесь по данным о выручке и при помощи условной конструкции `if` внутри цикла проверьте, превышает ли значение выручки пороговый показатель. Если выручка в текущей итерации превышает пороговое значение, увеличьте счетчик на +1. Выведите сообщение при помощи функции `print()` и `f-строк`.
#
#
# </p>
# </details>

# %%
# Ваш код здесь
# one method
data = [
    ('01.01', 100000), 
    ('01.02', 150000), 
    ('01.03', 250000)
]

def count_months(data, porog):
    n = 0
    for el in data:
        if el[1] > porog:
            n += 1
    print(f"Количество месяцев с выручкой выше {porog}: {n}")

count_months(data, 250000)

# %%
# two method
def count_m(data, porog):
    l = [el[1] for el in data] # выбираем из кортежей только данные по выручкам    
    n = sum(map(lambda x: x > porog, l)) # кол-во выручек больше порогового
    print(f"Количество месяцев с выручкой выше {porog}: {n}")

count_m(data, 10000)

# %% [markdown]
# ### Задание 9.

# %% [markdown]
# Прекрасно! Теперь мы можем легко считать месяцы с хорошими показателями по выручке. Однако полезно было бы знать не только количество этих месяцев, но и сами месяцы.
#
# Поэтому вы решили реализовать ещё одну функцию `filter_months`, которая будет всё так же принимать на вход два аргумента — **данные о выручке за определённый период** и **пороговое значение выручки**.
#
# Данные о выручке по-прежнему будут приходить в виде списка из кортежей следующего вида:
#
# ```python
# [
#     ('01.01', 100000),
#     ('01.02', 150000),
#     ('01.03', 250000),
#     ...
# ]
# ```
#
# где в каждом кортеже сначала указывается наименование месяца (в формате «первое число + порядковый номер месяца»), а затем — суммарная выручка за этот месяц.
#
# При этом список с данными о выручке может быть любой размерности и всегда содержит хотя бы один элемент.
#
# Теперь функция должна определять месяцы, в которых выручка превышает пороговое значение, и возвращать список с наименованиями месяцев.
#
# **Пример:**
#
# Допустим, на вход в функцию подаётся список с данными о выручке за 1-й квартал:
#
# ```python
# [
#     ('01.01', 100000),
#     ('01.02', 150000),
#     ('01.03', 250000)
# ]
# ```
#
# Также в качестве порогового значения подаётся значение `100000`.
#
# Тогда функция должна возвращать следующий список:
#
# ```python
# ['01.02', '01.03']
# ```
#
# **Примечание:**
#
# Обратите внимание, что в этой задаче функция должна возвращать список значений и не должна ничего печатать.
#
# Для решения задания попробуйте использовать **`lambda-функцию`** и **`функцию filter()`**.

# %% [markdown]
# <details>
# <summary>&#9658; Нажмите сюда, чтобы увидеть подсказку</summary>
#   <p>
#
# Что делать тут?
#
# Объявите функцию `filter_months`, которая принимает два аргумента: данные о выручке и пороговое значение.
#
# Далее используйте функцию `filter()` в паре с `lambda-функцией` для фильтрации нужных месяцев.
#
# С помощью `lambda-функции` проверьте, превышает ли значение выручки в каждом элементе пороговое значение. Затем с помощью функции `filter()` верните только те элементы, для которых условие истинно.
#
# Далее при помощи генератора списка или цикла проитерируйтесь по результату работы функции `filter()` и извлеките месяцы из кортежей.
#
# Сохраните полученный список в переменную и верните его с помощью оператора `return`.
#
# Не забывайте, что мы имеем дело со списком из кортежей, поэтому при проведении каждой итерации будем получать кортеж типа:
#
# ```(месяц, значение выручки)```
#
# К элементам кортежа можно обращаться по индексам. Значение выручки в кортеже всегда расположено на последнем месте.
#
# **Не забывайте**, что индексация в Python начинается с 0!
#
# А как создать генератор списка с функцией `filter()`, да ещё и с `lambda-функцией` внутри?
#
# Пример подобного синтаксиса:
#
# ```python
# # Список с числами
# num_list = [55, 150, 25, 18, 67]
#
# # Фильтруем данные и извлекаем только значения, превышающие 50, а с помощью генератора списка и цикла for итерируемся по отфильтрованным данным и добавляем в итоговый список каждый элемент, соответствующий условию
# num_above_50 = [num for num in filter(lambda x: x > 50, num_list)]
# print(num_above_50)
#
# # Результат
# [55, 150, 67]
# ```
#
# Данную задачу можно решить и без использования функции `filter()` в паре с `lambda-функцией`.
#
# Для этого необходимо в теле функции создать пустой список, в который будут добавляться месяца, когда выручка превышала пороговое значения.
#
# С помощью цикла `for` пройдитесь по данным о выручке и при помощи условной конструкции `if` внутри цикла проверьте, превышает ли значение выручки пороговый показатель. Если выручка в текущей итерации превышает пороговое значение, то добавьте значение месяца в ранее созданный список. Вспомните при помощи какого метода можно добавить новое значение в список.
#
# Используя ключевое слово `return`, верните из функции список с месяцами.
#
#
# </p>
# </details>

# %%
# Ваш код здесь
data = [
    ('01.01', 100000), 
    ('01.02', 150000), 
    ('01.03', 250000)
]

# %%
# first method
def filter_months(data, porog):
    dates = []
    for el in data:
        if el[1] > porog:
            dates.append(el[0])
    print(dates)

filter_months(data, 120000)

# %%
# second method
def filter_m(data, porog):
    data_filter = filter(lambda x: x[1] > porog, data) # фильтруем по выручкам кортежи
    return [el[0] for el in data_filter] # создаем списки дат от отфильтрованных кортежей
filter_m(data, 120000)

# %% [markdown]
# ### Задание 10.

# %% [markdown]
# Отправив написанные функции руководителю, вы решили сделать небольшой перерыв и узнать, как идут дела у Семёна. К сожалению, вы застали коллегу в плохом расположении духа. Вы тут же решили выяснить, что случилось: оказывается, Семёну подбросили трудную задачу, над которой он сидит с самого утра.
#
# Коллеги из другого отдела попросили написать программу, которая для любого курса будет генерировать названия учебных потоков. Они хотели бы передавать название самого курса и количество потоков, а на выходе получать название потока, составленное по следующему шаблону:
#
# `<Название курса>_<Номер потока>`
#
# То есть 5-му потоку курса `StartDA` будет соответствовать название `StartDA_5`.
#
# Семён объяснил, что пытался решить задачу с помощью функции, но коллег такой вариант не устроил. Им нужна не просто функция, которая создаёт все названия сразу, а именно генератор, который будет создавать по одному новому названию всякий раз, когда его об этом попросят. При этом генератор должен помнить, какие потоки уже были созданы ранее, и выдавать только новые названия.
#
# К сожалению, Семён не изучал генераторы и не понимает, как реализовать такую программу на Python. К счастью, вы генераторы проходили и поэтому решили помочь своему коллеге.
#
# Напишите генератор `stream_gen`, который будет принимать на вход два аргумента — **название курса** и **количество потоков**.
#
# За один вызов функции `next()` генератор должен возвращать одно новое название потока, составленное по приведённому выше шаблону. При этом общее количество потоков, которое может вернуть генератор, должно равняться количеству потоков, переданному в качестве второго аргумента.
#
# **Пример:**
#
# Если на вход генератор получает курс `StartDA` и количество потоков, равное 12 (допустим, каждый месяц будет генерироваться по одному потоку), тогда генератор за три вызова функции `next()` должен вернуть три значения:
#
# ```
# StartDA_1
# StartDA_2
# StartDA_3
# ```
# При этом максимальное количество потоков, которое может вернуть генератор, не должно превышать 12, т.е. последний сгенерированный поток будет иметь название `StartDA_12`.
#
# **Примечание:**
#
# Обратите внимание, что в этой задаче достаточно написать сам генератор. Помещать его в отдельную переменную и применять функцию `next()` на LMS не нужно.

# %% [markdown]
# <details>
# <summary>&#9658; Нажмите сюда, чтобы увидеть подсказку</summary>
#   <>p
#
# Генератор в Python представляет собой функцию, внутри которой обычно присутствует какой-нибудь цикл по элементам (итератор). Синтаксис создания генератора выглядит следующим образом:
#
# ```python
# def generator_name(arg1, arg2,...):
#     некоторый цикл:
#         yield result
# ```
# Для решения задачи вам необходимо создать генератор с названием `stream_gen`, который принимает на вход два аргумента: **название курса** и **количество потоков**.
#
# Далее напишите цикл `for` с функцией `range(количество_потоков)`, которая создаст последовательность **чисел от 0 до числа, содержащегося в переменной количество_потоков**. Например, если значение переменной `количество_потоков` равняется **3**, то `range(количество_потоков)` будет создавать последовательность `[0, 1, 2]`.
#
# В цикле на каждой итерации объедините название курса и номер потока. Для совмещения переменных в строку необходимо использовать оператор конкатенации строк "+". Не забудьте на каждой итерации увеличивать номер текущего потока на 1, так как индексация в Python начинается с 0!
#
# Сохраните получившуюся строку в переменную.
#
# Используйте ключевое слово `yield` для возврата значения и приостановки выполнения функции.
#
# Как это можно сделать?
#
# ```python
# # Создаем функцию-генератор с названием stream_gen
# def stream_gen(category, quantity):
#       # Запускаем цикл, который создает последовательность от 0 до значения, находящегося в переменной quantity
#       for index in range(quantity):
#           # Создаем переменную item_name, в которую сохраняем название категории, знак тире '—', номер категории +1,
#           # чтобы избежать значения 0 и включить крайнюю правую границу
#           item_name = category + '—' + str(index+1)
#           # Возвращаем значение и приостанавливаем выполнение функции
#           yield item_name
# ```
#
#
# Как проверить работу генератора?
#
# ```python
#  # Создаем генератор с значениями category = 'Books' и quantity = 3
# gen = stream_gen('Books', 3)
#
# # Запускаем цикл по нему
# for item in gen:
#     print(item)
#
# # Результат
# Books—1
# Books—2
# Books—3
# ```
#
# </p>
# </details>

# %%
# Ваш код здесь
def stream_gen(course, n): # n-кол-во потоков на курсе
    for n in range(1, n+1):
        course_n = f'{course}-{n}'
        yield course_n # генератор, который работает при цикле по нему

gen = stream_gen('start_DA',3)
for el in gen:
    print(el)

# %% [markdown]
# ### Задание 11.

# %% [markdown]
# На обеденном перерыве вы решили помочь Семёну закрепить знания о генераторах и предложили сыграть в игру.
#
# Вы возьмёте названия курсов из списка `valid_courses`:
#
# ```python
# ['Аналитик данных', 'Симулятор аналитика', 'Инженер данных', 'Основы Python', 'Симулятор SQL']
# ```
#
# Каждое название вы разобьёте на два слова и поместите их в разные списки. Список с первыми словами получите вы, а список со вторыми — Семён. В эти списки вы независимо друг от друга добавите ещё несколько слов, оставите только уникальные слова и перемешаете их. В результате получите два списка равной длины `first_part` и `second_part`. Например, такие:
#
# ```python
# ['Любитель', 'Симулятор', 'Искатель', 'Руководитель', 'Инженер', 'Аналитик', 'Потребитель', 'Основы']
# ```
#
# ```python
# ['гранатов', 'арбузов', 'финансов', 'инженера', 'аналитика', 'данных', 'SQL', 'Python']
# ```
#
# Затем из слов в полученных списках вы попробуете составить новые названия курсов. Объединять слова вы будете попарно через пробел (`' '`) с помощью генератора. Однако генерировать новые названия вы будете до тех пор, пока не получите любое настоящее название из списка `valid_courses`. Интересно, как много абсурдных названий вы сможете получить?
#
# Ваша идея Семёну понравилась, и вы решили написать генератор `course_gen`, который будет принимать на вход **два списка равной длины** (как в примере выше).
#
# За один вызов функции `next()` генератор должен возвращать одно «название курса», составленное из пар слов в списках, переданных генератору. При этом общее количество названий, которое может вернуть генератор, должно равняться количеству слов в любом из двух списков.
#
# После того, как напишите генератор `course_gen`, создайте переменную с этим генератором (можете назвать её `gen`).
#
# Далее в цикле на каждой итерации запускайте получившийся генератор `gen` и печатайте название курса до момента, пока не получится составить любой курс из списка `valid_courses`. Как только будет получено название из этого списка, напечатайте последнее сгенерированное название и остановите генерацию.
#
# В результате ваша программа должна напечатать столько абсурдных «названий курсов», сколько получится до первого настоящего названия. Настоящее название нужно напечатать последним.
#
# Если настоящее название будет получено на первой итерации, то напечатайте только это название и также остановите генерацию.
#
# Если за всю работу цикла название курса так и не получится составить, то ваш код должен просто вывести все сгенерированные названия. Не забудьте проследить, чтобы в конце цикла не появилась ошибка `StopIteration`.
#
# **Пример:**
#
# Допустим, вы написали генератор `course_gen` и создали переменную `gen` с этим генератором, передав в него списки `first_part` и `second_part` из примера выше.
#
# Тогда цикл с генерацией и печатью названий должен вывести все названия до первого настоящего названия (`Аналитик данных`), включая его:
#
# ```
# Любитель гранатов
# Симулятор арбузов
# Искатель финансов
# Руководитель инженера
# Инженер аналитика
# Аналитик данных
# ```
#
# При этом последние возможные названия (`Разработчик SQL` и `Основы Python`) не должны быть сгенерированы.
#
# Если бы `Аналитик данных` получился с первой попытки, то остальные названия не были бы сгенерированы и программа просто напечатала бы:
#
# ```
# Аналитик данных
# ```
#
# **Примечание:**
#
# Представьте, что в эту игру вы будете играть с Семёном не один раз. Список с «правильными названиями» всегда один, но каждый раз на вход в генератор могут поступать разные списки со словами в разной последовательности. При этом ваш код должен работать на разных данных.

# %% [markdown]
# Списки `first_part`, `second_part` и `valid_courses` уже созданы:

# %%
first_part = ['Любитель', 'Симулятор', 'Искатель', 'Руководитель', 'Инженер', 'Основы', 'Аналитик', 'Потребитель' ]
second_part = ['гранатов', 'арбузов', 'финансов', 'инженера', 'аналитика', 'Python', 'данных', 'SQL']

valid_courses = ['Аналитик данных', 'Симулятор аналитика', 'Инженер данных', 'Основы Python', 'Симулятор SQL']

# %% [markdown]
# <details>
# <summary>&#9658; Нажмите сюда, чтобы увидеть подсказку</summary>
#   <p>
#
# А что делать тут?
#
# Создайте генератор с названием `course_gen`, который принимает на вход два списка равной длины.
#
# В теле генератора при помощи цикла `for` пройдитесь по двум спискам, переданным генератору в качестве аргументов. Чтобы пройтись в одном цикле сразу по двум спискам, используйте функцию `zip()`.
#
# На каждой итерации цикла используйте ключевое слово `yield` для возврата «названия курса», составленного из пар слов, разделенных пробелом `(' ')`:
#
# ```python
# def generator_name(arg1, arg2):
#     for part_one, part_two in zip(arg1, arg2):
#         yield part_one + ' ' + part_two
# ```
#
# Затем создайте объект генератора, вызвав функцию `course_gen` с аргументами `first_part`, `second_part`. Не забудьте сохранить данные в переменную.
#
# Напишите цикл `for` для итерации по значениям, возвращаемым генератором. На каждой итерации с помощью функции `print()` печатайте сгенерированное значение и сразу же с помощью условной конструкции `if` проверяйте, содержится ли это значение в списке `valid_courses`. Если оно есть в списке, прервите цикл с помощью оператора `break`.
#
# </p>
# </details>

# %%
# Ваш код здесь

def course_gen(first_part, second_part):
    for e,l in zip(first_part, second_part):
        course = f'{e} {l}'
        yield course
        
gen = course_gen(first_part, second_part)
for el in gen:    
    print(el)
    if el in valid_courses:
            break

# %% [markdown]
# ### Задание 12.

# %% [markdown]
# Вернувшись с обеда в хорошем настроении, вы решили приступить к ещё одной задаче из списка. В этот раз будем считать стоимость курсов с учётом скидок для отдела управления продуктом.
#
# У компании karpov.courses много разных курсов, и перед запуском промоакций вычислять новую стоимость курсов вручную неудобно. Поэтому коллеги попросили написать код, который будет делать это автоматически.
#
# Напишите функцию `apply_discount`, которая будет принимать два аргумента — **словарь с ценами на курсы** и **размер скидки**.
#
# Словарь с ценами на курсы имеет следующий вид:
#
# ```python
# {
#     'StartDA': 80000,
#     'StartML': 150000,
#     'StartDE': 90000,
#     'HardDA': 120000,
#     'HardML': 150000,
#     ...
# }
# ```
#
# Количество курсов в словаре может быть любым, ведь со временем в karpov.courses наверняка появятся новые программы.
#
# Размер скидки всегда выражен целым числом от `0` до `100`. Его будут передавать в процентах, но без знака `%`.
#
# По умолчанию аргумент, отвечающий за **размер скидки**, должен быть равен `0`.
#
# Функция должна возвращать словарь такого же вида и размерности, который пришёл на вход, но с обновлёнными ценами. Если скидка не указывается или размер скидки по умолчанию не меняется, то должен возвращаться словарь с курсами и ценами без изменений.
#
# Новые цены с учётом скидки также необходимо округлить до целого числа и, соответственно, выразить целыми числами.
#
# **Пример:**
#
# Допустим, на вход в функцию подаётся следующий словарь с курсами и ценами:
#
# ```python
# {
#     'StartDA': 80000,
#     'StartML': 150000,
#     'StartDE': 90000,
#     'HardDA': 120000,
#     'HardML': 150000
# }
# ```
#
# При этом размер скидки указывается равным `10`.
#
# Тогда функция должна вернуть следующий словарь:
#
# ```python
# {
#     'StartDA': 72000,
#     'StartML': 135000,
#     'StartDE': 81000,
#     'HardDA': 108000,
#     'HardML': 135000
# }
# ```
#
# Если размер скидки не указывается, функция должна вернуть исходный словарь, поскольку скидка по умолчанию равна 0.
#
# **Примечание:**
#
# Обратите внимание, что в этой задаче функция должна возвращать словарь с курсами и ценами и не должна ничего печатать.

# %% [markdown]
# <details>
# <summary>&#9658; Нажмите сюда, чтобы увидеть подсказку</summary>
#   <p>
#
# Объявите функцию `apply_discount`, которая принимает два аргумента: словарь с ценами на курсы и размер скидки.
#
# Аргументы можно назвать как угодно — например, `prices_dict` и `discount`. При этом у `discount` значение по умолчанию необходимо установить равным `0`.
#
# В теле функции создайте пустой словарь, в который будут добавляться обновлённые цены на курсы. Его можно назвать `prices_dict_upd`.
#
# Затем при помощи цикла `for` проитерируйтесь по ключам словаря `prices_dict`.
#
# На каждой итерации получайте значения из словаря по ключам (цены курсов), производите расчёт новой цены курса с учётом скидки (`discount`) и добавляйте новую цену в заранее созданный словарь `prices_dict_upd` по тому же ключу (курсу), по которому получали исходную цену из словаря `prices_dict`.
#
# Вычислить новую цену на курс можно по следующей формуле:
#
# ```python
# цена_со_скидкой = обычная_цена - (обычная_цена * скидка / 100)
# ```
# Не забудьте округлить новые цены до целого числа.
#
# Для добавления ключа в словарь можно использовать простое присваивание:
#
# ```python
# my_dict = {}
# my_dict['key1'] = 'value1'
# print(my_dict)
#
# # Вывод
# {'key1': 'value1'}
# ```
# В конце после цикла `for` верните новый словарь c помощью оператора `return`.
#
# </p>
# </details>

# %%
# Ваш код здесь

data = {
    'StartDA': 80000, 
    'StartML': 150000, 
    'StartDE': 90000, 
    'HardDA': 120000, 
    'HardML': 150000
}

def apply_discount(data, discount=0):
    data_discount = {}
    for el in data.items():
        k = el[0]
        v = round(el[1] - el[1] * discount / 100)
        data_discount.update({k: v})
    return data_discount
apply_discount(data, 50)

# %% [markdown]
# ### Задание 13.

# %% [markdown]
# Ещё одну задачу можно вычеркнуть из списка! Теперь пора выяснить, какой сюрприз в этот раз подготовил отдел сопровождения студентов.
#
# Из описания задачи вы поняли, что вас просят написать программу, которая будет получать оценки студента за задания в уроке, считать средний балл и автоматически определять, прошёл студент урок или нет.
#
# Но есть один важный нюанс: количество заданий в уроке может быть любым (но не равным 0), а значит, в функцию может быть передано произвольное число аргументов (баллов).
#
# Напишите функцию `check_result`, которая будет принимать **произвольное число аргументов**. Каждый аргумент — это **число баллов, полученных студентом за задание в уроке**.
#
# Функция должна вычислять средний балл за все задания, округлять это значение до 1 знака после запятой и определять итоговый результат.
#
# При этом заранее известно, что за каждое задание студент может получить от 0 до 10 баллов. Если средний балл за все задания превышает 5, то считается, что студент успешно завершил урок и его результат `passed`, в противном случае — результат `failed`.
#
# Функция должна возвращать словарь, в котором по ключам `avg_points` и `result` будут указаны соответственно средний балл за задания и результат.
#
# **Пример:**
#
# Допустим, на вход в функцию подаётся 6 значений: `1, 5, 7, 10, 0, 4`
#
# Тогда функция должна определить средний балл, сравнить его с проходным баллом (5) и вернуть следующий словарь:
#
# ```python
# {'avg_points': 4.5, 'result': 'failed'}
# ```
#
# **Примечание:**
#
# Обратите внимание, что в этой задаче функция должна возвращать словарь и не должна ничего печатать.
#
# Заранее известно, что урок не может быть пустым и функция получает на вход как минимум один аргумент.

# %% [markdown]
# <details>
# <summary>&#9658; Нажмите сюда, чтобы увидеть подсказку</summary>
#   <p>
#
# А как быть тут?
#
# Объявите функцию `check_result`, которая принимает произвольное число аргументов. Поскольку число параметров вам неизвестно, то в качестве аргумента поставьте параметр `*args` со звёздочкой. Тут важна именно звёздочка, а вместо `args` можно подставить любое другое имя.
#
# Далее вычислите среднее значение переданных в функцию аргументов. Вспомните, как производили вычисление среднего ранее: с помощью `sum(args)` найдите сумму всех аргументов и разделите на их количество `len(args)`.
#
# Для округления значения воспользуйтесь функцией `round`.
#
# Для удобства сохраните результат в переменную `avg_points`.
#
# Используя условную конструкцию `if/else` сравните средний балл со значением 5:
# * если среднее значение больше 5, создайте переменную `result` и положите в неё значение `'passed'`
# * иначе создайте переменную `result` и положите в неё значение `'failed'`
#
# В конце после условной конструкции через оператор `return` верните словарь с ключами `'avg_points'` и `'result'`, где значениями по ключам будут соответственно переменные `avg_points` и `result`
#
# </p>
# </details>

# %%
# Ваш код здесь

def check_result(*args):
    avg_points = sum(args) / len(args)
    result ='passed' if avg_points > 5  else 'failed' # тернарный оператор
    return {'avg_points': avg_points, 'result': result}

check_result(9,9,9,8)

# %% [markdown]
# ### Задание 14.

# %% [markdown]
# Коллеги из отдела сопровождения в восторге от придуманной вами функции, она значительно облегчает решение их рабочих задач!
#
# Теперь они просят написать функцию, которая поможет следить за успеваемостью учащихся и формировать топ студентов по числу набранных баллов.
#
# Как обычно, с источником данных вам не повезло, и результаты студентов будут приходить в виде списка из словарей следующего вида:
#
# ```python
# [
#     {'name': 'Иван Иванов', 'points': [4, 3, 5, 4, 4, 3]},
#     {'name': 'Елена Петрова', 'points': [5, 4, 4, 3, 5, 8]},
#     {'name': 'Сергей Сидоров', 'points': [3, 2, 5, 2, 3, 6]},
#     {'name': 'Ольга Николаева', 'points': [4, 4, 4, 4, 4, 7]},
#     {'name': 'Павел Козлов', 'points': [2, 3, 5, 3, 2, 5]}
# ]
# ```
#
# Количество словарей (студентов) в списке может быть любым. Но в каждом словаре всегда будет два ключа. По ключу `'name'` будет указано имя студента, а по ключу `'points'` — список с баллами студента за задания в уроке.
#
# Для начала вы решили реализовать функцию `sort_students_by_points`, которая будет принимать на вход **список словарей**, сортировать словари (студентов) по сумме набранных баллов (от наибольшего значения к наименьшему) и возвращать отсортированный список словарей.
#
# **Пример:**
#
# Допустим, на вход в функцию подаётся указанный выше список из словарей.
#
# Тогда функция должна вернуть отсортированный список:
#
# ```python
# [
#     {'name': 'Елена Петрова', 'points': [5, 4, 4, 3, 5, 8]},
#     {'name': 'Ольга Николаева', 'points': [4, 4, 4, 4, 4, 7]},
#     {'name': 'Иван Иванов', 'points': [4, 3, 5, 4, 4, 3]},
#     {'name': 'Сергей Сидоров', 'points': [3, 2, 5, 2, 3, 6]},
#     {'name': 'Павел Козлов', 'points': [2, 3, 5, 3, 2, 5]}
# ]
#
# ```
# При этом последовательность студентов в новом словаре изменилась в соответствии с суммой набранных студентами баллов.
#
# **Примечание:**
#
# Обратите внимание, что в этой задаче функция должна возвращать отсортированный список и не должна ничего печатать. Возвращать значение суммы баллов и изменять структуру словарей не нужно.
#
# Для решения задания используйте **lambda-функцию** и **функцию sorted()**.

# %% [markdown]
# <details>
# <summary>&#9658; Нажмите сюда, чтобы увидеть подсказку</summary>
#   <p>
#
# Для решения этого задания вам необходимо использовать функцию `sorted()` совместно с `lambda-функцией`.
#
# Создайте функцию с названием `sort_students_by_points`, которая принимает на вход один аргумент — список со словарями.
#
# В теле функции вызовите функцию `sorted()`:
#
# * в качестве итерируемого объекта, элементы которого нужно отсортировать, укажите список, подаваемый в функцию `sort_students_by_points`
# * в аргумент `key` в качестве ключа сортировки (вычисляемого значения, по которому производится сортировка) передайте `lambda-функцию`, которая обращается к значению словаря по ключу `'points'` и с помощью функции `sum()` вычисляет сумму баллов каждого студента
# * укажите аргумент `reverse=True`, чтобы сортировка происходила в обратном порядке, то есть по убыванию суммы баллов
#
# Сохраните результат работы функции `sorted()` в переменную!
#
# С помощью `return` верните отсортированный список студентов.
#
# Пример использования функции `sorted()` с `lambda-функцией` в ключе сортировки:
# ```python
#
# # Объявляем функцию sort_students_by_age
# def sort_students_by_age(students):
#     # В функции sorted указываем в качестве итерируемого объекта список students
#     # В ключ сортировки key передаём lambda-функцию
#     sorted_students = sorted(students, key=lambda x: x[1])
#     # Возвращаем отсортированный список
#     return sorted_students
#
# # Пример использования функции
# students = [('Alice', 20, 3.5), ('Bob', 22, 4.0), ('Charlie', 19, 3.2)]
# sorted_students = sort_students_by_age(students)
# print(sorted_students)
#
# # Результат
# [('Charlie', 19, 3.2), ('Alice', 20, 3.5), ('Bob', 22, 4.0)]
# ```
# </p>
# </details>

# %%
# Ваш код здесь

students_by_points = [
    {'name': 'Иван Иванов', 'points': [4, 3, 5, 4, 4, 3]},
    {'name': 'Елена Петрова', 'points': [5, 4, 4, 3, 5, 8]},
    {'name': 'Сергей Сидоров', 'points': [3, 2, 5, 2, 3, 6]},
    {'name': 'Ольга Николаева', 'points': [4, 4, 4, 4, 4, 7]},
    {'name': 'Павел Козлов', 'points': [2, 3, 5, 3, 2, 5]}
]

# %%
def sort_students_by_points(data):
    sorted_points = sorted(data, key=lambda x: sum(x['points']), reverse=True)    
    return sorted_points
sort_students_by_points(students_by_points)

# %%
sorted_points = sorted(students_by_points, key=lambda x: sum(x['points']), reverse=True)
sorted_points

# %%
a = [5,2,3,4,1]
b = [10,11,12,13,14]
c = [20,21,22,23,24]
sorted(a)

# %% [markdown]
# ### Задание 15.

# %% [markdown]
# Посмотрев на полученный результат, вы решили, что функцию можно немного улучшить.
#
# Во-первых, можно сделать так, чтобы функция печатала имена студентов, их позицию в рейтинге и сумму набранных баллов. Во-вторых, можно добавить аргумент, отвечающий за количество студентов в топе по успеваемости.
#
# Напишите новую функцию `sort_students_by_points_upd`, которая теперь будет принимать на вход два аргумента — **список со словарями** и **количество студентов, которое нужно включить в топ по успеваемости**.
#
# Список со словарями по-прежнему имеет следующий вид:
#
# ```python
# [
#     {'name': 'Иван Иванов', 'points': [4, 3, 5, 4, 4, 3]},
#     {'name': 'Елена Петрова', 'points': [5, 4, 4, 3, 5, 8]},
#     {'name': 'Сергей Сидоров', 'points': [3, 2, 5, 2, 3, 6]},
#     {'name': 'Ольга Николаева', 'points': [4, 4, 4, 4, 4, 7]},
#     {'name': 'Павел Козлов', 'points': [2, 3, 5, 3, 2, 5]}
# ]
# ```
#
# Второй аргумент, отвечающий за число студентов в топе, должен иметь значение по умолчанию, равное `3`.
#
# Функция должна определять топ студентов по сумме набранных ими баллов и с помощью `f-строк` печатать их в следующем формате:
#
# `<Номер студента в топе>. <Имя Фамилия>, <Сумма баллов>`
#
# Информация о каждом студенте должна печататься на новой строке. При этом функция должна вывести столько студентов, сколько указано во втором аргументе. Без передачи в функцию значения второго аргумента она должна выводить топ-3 студентов.
#
#
# **Пример:**
#
# Допустим, на вход в функцию подаётся указанный выше список из словарей.
#
# При этом значение второго аргумента остаётся без изменений.
#
# Тогда функция должна вывести на печать следующее:
# ```
# 1. Елена Петрова, 29
# 2. Ольга Николаева, 27
# 3. Иван Иванов, 23
# ```
#
# **Примечание:**
#
# Обратите внимание, что в этой задаче функция не должна возвращать словарь, а должна печатать топ студентов в требуемом формате.
#
# Для решения задания используйте **lambda-функцию** и **функцию sorted()**.

# %% [markdown]
# <details>
# <summary>&#9658; Нажмите сюда, чтобы увидеть подсказку</summary>
#   <p>
#
# Для решения задачи необходимо доработать функцию из прошлого шага.
#
# Создайте функцию `sort_students_by_points_upd`, которая принимает два аргумента: список со словарями и количество студентов, которых нужно вывести в топе. При этом значение второго аргумента необходимо установить равным `3`.
#
# Далее, по аналогии с прошлым заданием, в теле функции вызовите функцию `sorted()`:
#
# * в качестве итерируемого объекта, элементы которого нужно отсортировать, укажите список, подаваемый в функцию `sort_students_by_points_upd`
# * в аргумент `key` в качестве ключа сортировки (вычисляемого значения, по которому производится сортировка) передайте `lambda-функцию`, которая обращается к значению словаря по ключу `'points'` и с помощью функции `sum` вычисляет сумму баллов каждого студента
# * укажите аргумент `reverse=True`, чтобы сортировка происходила в обратном порядке, то есть по убыванию суммы баллов
#
# Сохраните результат работы функции `sorted()` (отсортированный список словарей) в переменную.
#
# Теперь возьмите из этого списка столько элементов, сколько передано вторым аргументом, отвечающим за количество студентов в топе. Допустим, этот аргумент вы назвали `top`. Тогда вам нужно сделать срез от нулевого элемента до значения `top`.
#
# **Не забывайте**, что индексация в Python начинается с 0!
#
# Например, когда, мы указываем `[:top]`, это означает, что мы берём все элементы списка с индексами до `top`, не включая элемент с индексом `top`. То есть мы извлекаем данные, начиная с первого элемента списка и заканчивая элементом списка с индексом `top - 1`.
#
# Не забудьте сохранить срез отсортированного списка в новую переменную!
#
# А как быть дальше?
#
# Элементами полученного среза являются словари:
#
# ```python
# [{'name': 'Алиса Демидова', 'points': [5, 5, 5, 5, 5, 10]},
#  {'name': 'Мария Волкова', 'points': [4, 4, 5, 4, 3, 7]}, ...]
# ```
#
# Получить значение в каждом словаре можно по ключу.
#
# Создайте цикл `for` с функцией `enumerate()`, который будет итерироваться по пронумерованным элементам среза. На каждой итерации считайте сумму баллов и при помощи функции `print()` и `f-строк` выводите номер студента в топе, имя и сумму баллов.
#
# Пример похожей структуры кода:
#
# ```python
# # Объявляем функцию sort_students_by_age
# def sort_students_by_age(students):
#     # В функции sorted указываем в качестве итерируемого объекта список students
#     # В ключ сортировки key передаём lambda-функцию
#     sorted_students = sorted(students, key=lambda x: x['age'])
#     # Итерируемся по списку словарей и выводим студентов и их возраст
#     for student in sorted_students:
#         student_name = student['name']
#         student_age = student['age']
#         print(f'{student_name}, {student_age} years old')
#
# # Пример использования функции
# students = [{'name': 'Alice', 'age': 20}, {'name': 'Bob', 'age': 25}, {'name': 'Anna', 'age': 22}]
# sort_students_by_age(students)
#
# # Результат
# Alice, 20 years old
# Anna, 22 years old
# Bob, 25 years old
# ```
# </p>
# </details>

# %%
# Ваш код здесь
students_by_points = [
    {'name': 'Иван Иванов', 'points': [4, 3, 5, 4, 4, 3]},
    {'name': 'Елена Петрова', 'points': [5, 4, 4, 3, 5, 8]},
    {'name': 'Сергей Сидоров', 'points': [3, 2, 5, 2, 3, 6]},
    {'name': 'Ольга Николаева', 'points': [4, 4, 4, 4, 4, 7]},
    {'name': 'Павел Козлов', 'points': [2, 3, 5, 3, 2, 5]}
]

# %%
def sort_students_by_points_upd(data, top=3):    
    sorted_st_b_p = sorted(data, key=lambda x: sum(x['points']), reverse=True)
    for n, el in enumerate(sorted_st_b_p[:top], 1):    
        name = el['name']
        sum_points = sum(el['points'])
        print(f'{n}. {name}, {sum_points}')
        
sort_students_by_points_upd(students_by_points, 2)

# %% [markdown]
# ### Задание 16.

# %% [markdown]
# Похоже, сегодня у вас действительно насыщенный день! Но осталась всего одна задача из списка, который прислал Анатолий Карпов. И выглядит она в целом не такой уж и сложной.
#
# В базе данных karpov.courses каждый студент имеет уникальный логин, который используется для доступа к онлайн-курсам. Порой студенты забывают свой логин, а при обращении за помощью при восстановлении доступа к LMS указывают только электронную почту. Конечно, если покопаться в базе данных и подёргать коллег, можно выяснить логин студента, но каждый раз делать так неудобно. Поэтому специалисты технической поддержки просят вас придумать более оптимальное решение.
#
# Напишите функцию `find_user`, которая будет принимать на вход два аргумента — **данные студентов** и **почту, по которой нужно найти студента**.
#
# Данные студентов представлены в виде словаря, где ключами являются логины студентов, а значениями по ключам — другие словари, в которых по ключам `'name'`, `'surname'` и `'email'` указаны соответствующие характеристики:
#
# ```python
# {
#     'alice.dem': {'name': 'Алиса', 'surname': 'Демидова', 'email': 'alice.wonderland99@mail.ru'},
#     'mikhail.val': {'name': 'Михаил', 'surname': 'Валетов', 'email': 'supermisha512@gmail.com'},
#     'anton.kar': {'name': 'Антон', 'surname': 'Каргин', 'email': 'kargin.aa00@mail.ru'},
#     'maria.vol': {'name': 'Мария', 'surname': 'Волкова', 'email': 'maryvolkova1201@hotmail.com'},
#     'roman.tok': {'name': 'Роман', 'surname': 'Токарев', 'email': 'tokarevv.roman85@gmail.com'}
# }
# ```
#
# Функция должна попытаться найти студента с указанным почтовым адресом и в случае, если студент с таким почтовым адресом есть, с помощью `f-строки` вывести сообщение следующего формата:
#
# ```С почтой <email> найден пользователь <login>```
#
# Если же студента с указанной почтой в данных нет, функция должна вывести строку:
#
# ```Пользователь с почтой <email> не найден```
#
# На месте значений `<login>` и `<email>` в выводимом результате должны быть соответственно значения логинов (ключи словаря, переданного на вход в функцию) и почты студентов (значения по ключу `'email'` во вложенных словарях).
#
#
# **Пример:**
#
# Допустим, на вход в функцию подаётся указанный выше словарь со словарями.
#
# При этом для поиска указывается почта `'alice.wonderland99@mail.ru'`.
#
# Тогда функция должна напечатать следующее сообщение:
#
# ```С почтой alice.wonderland99@mail.ru найден пользователь alice.dem```
#
#
# **Примечание:**
#
# Обратите внимание, что в этой задаче функция не должна возвращать словарь, а должна печатать сообщение в требуемом формате.
#
# Также заранее известно, что одному логину в данных может соответствовать только одна почта.

# %% [markdown]
# <details>
# <summary>&#9658; Нажмите сюда, чтобы увидеть подсказку</summary>
#   <p>
#
# Рассмотрим структуру передаваемого словаря на следующем примере:
#
# ```python
# user_dict = {'alice.dem': {'name': 'Алиса', 'surname': 'Демидова', 'email': 'alice.wonderland99@mail.ru'}}
# ```
#
# Чтобы получить доступ к почтовому адресу, необходимо обратиться к значению в словаре `user_dict` по ключу `'alice.dem'` (логину студента), а потом к значению во вложенном словаре по ключу `'email'` (почте):
#
# ```python
# student_dict['alice.dem']['email']
#
# # Результат
# 'alice.wonderland99@mail.ru'
# ```
#
# Для решения задания сначала объявите функцию `find_user`, которая принимает на вход два аргумента: словарь `user_data` (данные пользователей) и `email` (почтовый адрес, который мы ищем).
#
# Затем с помощью цикла `for` пройдитесь по каждому элементу в словаре `user_data`. В условном операторе `if` проверьте, совпадает ли почтовый адрес пользователя с искомым значением почты, передаваемой в аргументе функции.
#
# Если совпадает, то с помощью функции `print()` и `f-строк` напечатайте следующее сообщение:
#
# ```С почтой <email> найден пользователь <login>```
#
# После нахождения пользователя с искомым почтовым адресом завершите выполнение функции с помощью оператора `return`.
#
# В случае, если ни один пользователь с искомым почтовым адресом не был найден, с помощью функции `print()` и `f-строк` выведите сообщение:
#
# ```Пользователь с почтой <email> не найден```
#
# Соотвествующий код необходимо указать после цикла `for`.
#
# </p>
# </details>

# %%
# Ваш код здесь

data = {
    'alice.dem': {'name': 'Алиса', 'surname': 'Демидова', 'email': 'alice.wonderland99@mail.ru'},
    'mikhail.val': {'name': 'Михаил', 'surname': 'Валетов', 'email': 'supermisha512@gmail.com'},
    'anton.kar': {'name': 'Антон', 'surname': 'Каргин', 'email': 'kargin.aa00@mail.ru'},
    'maria.vol': {'name': 'Мария', 'surname': 'Волкова', 'email': 'maryvolkova1201@hotmail.com'},
    'roman.tok': {'name': 'Роман', 'surname': 'Токарев', 'email': 'tokarevv.roman85@gmail.com'}
}

# %%
def find_user(dict_data, user_email):    
    for el in data.items():
        email = el[1]['email']
        login = el[0]
        if email == user_email:
            return f'С почтой {email} найден пользователь {login}'
        
    print(f'Пользователь с почтой {user_email} не найден')
        
user_email = 'supermisha512@gmail.com'
find_user(data, user_email)

# %% [markdown]
# ### Задание 17.

# %% [markdown]
# Вот вы и на финишной прямой. Рабочий день подходит к концу, осталось на всякий случай проверить сообщения в Telegram. Ну как всегда... Какое-то важное сообщение под занавес рабочего дня. Впрочем, ничего удивительного.
#
# Ваша коллега Ольга сегодня совсем в огне и просит вас подхватить пару задач. Разве можете вы отказать? Тем более, её задачи, скорее всего, будут посложнее и тем интереснее!
#
# Первая задача снова про метрики. Руководители ключевых направлений бизнеса очень любят следить за разными показателями, и им хочется иметь под рукой инструмент, который помог бы оперативно их считать.
#
# Как правило, по одним и тем же данным можно посчитать сразу несколько метрик. Например, по данным о покупках можно посчитать выручку, количество заказов, количество покупателей и даже средний чек. Поэтому нужно придумать что-то, что позволит выбирать нужный показатель и производить расчёты по соответствующим формулам.
#
# Что же тогда можно предложить коллегам? Конечно, калькулятор метрик! Они будут загружать в него данные о покупках пользователей, выбирать интересующую их метрику, а калькулятор будет подстраиваться под их запрос.
#
# Данные о покупках пользователей будут приходить в виде списка, элементами которого также являются списки. Каждый вложенный список будет соответствовать покупкам одного пользователя, а каждое значение в списке — стоимости каждой его покупки. Например, данные могут выглядеть так:
#
#
# ```python
# [
#     [75000, 53000, 31000],
#     [27500, 135000],
#     [27500, 95000],
#     [100000],
#     [53000, 45000, 27500],
#     [32000, 100000, 27500, 53000]
# ]
# ```
# В этом списке 6 пользователей с разным количеством покупок. У первого пользователя их три, а у четвёртого всего одна.
#
# Также заранее известно, что у каждого пользователя в данных есть хотя бы одна покупка, списки не могут быть пустыми.
#
# Ваших коллег будут интересовать следующие метрики:
#
# * `revenue` — выручка; сумма всех значений (стоимостей покупок) в списке.
# * `orders` — число покупок (заказов); количество всех значений в списке.
# * `paying_users` —  число платящих пользователей (покупателей); количество списков внутри списка.
# * `aov` — средний чек; выручка, делённая на число покупок (заказов); округляется до 2 знаков после запятой.
# * `aov_alt` — средний чек, посчитанный альтернативным способом; для каждого пользователя вычисляется средний чек (сумма покупок пользователя, делённая на количество его покупок), затем находится усреднённый средний чек (суммируются все средние чеки пользователей и делятся на общее количество пользователей); округляется до 2 знаков после запятой.
#
# Напишите функцию `calculate_metric`, которая будет иметь два аргумента — **данные о покупках пользователей** и **название метрики**. Второй аргумент должен иметь значение по умолчанию, равное `'revenue'`.
#
# Функция должна принимать данные о покупках, считать передаваемую в качестве второго аргумента метрику и возвращать её значение. При этом, если значение метрики не передаётся, функция по умолчанию должна считать выручку (`'revenue'`).
#
# Если в качестве второго аргумента передаётся название метрики не из списка отслеживаемых метрик (`revenue`, `orders`, `paying_users`, `aov`, `aov_alt`), функция не должна ничего считать, а должна вывести следующее сообщение об ошибке:
#
# ```Неверно указана метрика.```
#
# Таким образом, вы должны реализовать калькулятор метрик, который позволит коллегам выбирать метрику для расчёта и автоматически получать рассчитанное значение.
#
#
# **Пример:**
#
# Допустим, на вход в функцию подаётся указанный выше список с данными о покупках. В качестве метрики указывается `aov_alt`.
#
# Тогда функция должна посчитать среднее значение в каждом вложенном списке, поделить его на количество этих списков и вернуть значение `65076.39`.
#
# **Примечание:**
#
# Обратите внимание, что в этой задаче в зависимости от ситуации функция должна либо возвращать значение метрики, либо печатать сообщение об ошибке.
#
# Рекомендуем сначала отдельно посчитать все метрики, проверить работу своего кода, а потом поместить логику расчёта в тело функции `calculate_metric`.

# %% [markdown]
# <details>
# <summary>&#9658; Нажмите сюда, чтобы увидеть подсказку</summary>
#   <p>
#
# Создайте функцию `calculate_metric`, которая принимает два аргумента: список списков, представляющих данные, и строку с наименованием метрики, которую необходимо вычислить. Аргументы можно назвать, например, `data` и `metric`.
#
# В написании калькулятора метрик вам помогут условные операторы `if`, которые будут проверять независимые условия и в зависимости от их истинности выполнять соответствующий блок кода:
#
# ```python
# if какое-то условие:
#     Код, который выполняется, если условие верно
# if какое-то другое независимое условие:
#     Код, который выполняется, если другое независимое условие верно
# ...
# ```
#
# Для начала проверьте, относится ли значение, переданное в аргумент `metric`, к числу допустимых метрик. Это можно сделать при помощи оператора `not in`:
#
# ```python
# metric not in ['revenue', 'orders', 'students', 'aov', 'aov_alt']
# ```
# Если значение `metric` не соответствует ни одной из указанных метрик, с помощью функции `print()` выведите сообщение:
#
# ```Неверно указана метрика.```
#
# Затем сразу завершите работу функции, используя оператор `return`.
#
# Теперь в теле функции необходимо для каждой метрики написать свой блок с `if`, который будет проверять название метрики и в зависимости от её названия проводить расчёты и выводить результат.
#
# Пример кода на примере расчёта выручки (`revenue`):
#
#
# ```python
# # Проверяем, какому значению метрики равна переданная в аргумент функции метрика
# if metric == 'revenue':
#     # Создаем переменную revenue, в которой будем накапливать значение общей выручки
#     revenue = 0
#     # Запускаем цикл по списку data
#     for i in data:
#         # На каждой итерации цикла к revenue добавляется сумма всех элементов во внутренних списках i
#         revenue += sum(i)
#     # Возвращаем значение выручки
#     return revenue
# ```
#
# Далее аналогичным образом необходимо написать такие же блоки кода с `if` для остальных метрик, учитывая специфику их расчёта.
#
# </p>
# </details>

# %%
# Ваш код здесь

data = [
    [75000, 53000, 31000],
    [27500, 135000],
    [27500, 95000],
    [100000],
    [53000, 45000, 27500],
    [32000, 100000, 27500, 53000]
]

# %%
def calculate_metric(data_list, metric='revenue'):
    if metric not in ['revenue', 'orders', 'paying_users', 'aov', 'aov_alt']:
        print('Неверно указана метрика.')
        return    
    
    if metric == 'revenue':
        revenue = 0
        for n, el in enumerate(data, 1):
            revenue += sum(el)
        return revenue
    
    if metric == 'orders':
        orders = 0
        for n, el in enumerate(data, 1):
            orders += len(el)
        return orders
    
    if metric == 'paying_users':        
        for n, el in enumerate(data, 1):
            paying_users = n
        return paying_users
    
    if metric == 'aov':
        revenue = 0
        orders = 0
        for n, el in enumerate(data, 1):
            revenue += sum(el)
            orders += len(el)
            aov = round(revenue/orders, 2)            
        return aov
    
    if metric == 'aov_alt':
        aov_alt = 0
        for n, el in enumerate(data, 1):
            aov_user = sum(el)/len(el)
            aov_alt += aov_user
            paying_users = n
        aov_alt = round(aov_alt/paying_users, 2)
        return aov_alt
        
calculate_metric(data, 'aov_alt')

# %%
(53125+41833.3+100000+61250+81250+53000)/6

# %% [markdown]
# ### Задание 18.

# %% [markdown]
# Фух, с одной задачей справились, переходим ко второй. Кажется, здесь тоже что-то необычное: будем делать не калькулятор, а конструктор.
#
# Отделу по работе с интернет-трафиком нужен конструктор UTM-ссылок, которые будут использовать в рекламных кампаниях. Эти ссылки будут вести на сайт так же, как и обычные ссылки, но вместе с тем будут передавать в систему аналитики важную информацию, которая поможет отследить источники переходов и проанализировать трафик. Например, с помощью таких ссылок аналитики смогут узнать, какие посты в соцсетях просматривают чаще других или какая реклама лучше конвертирует в покупку.
#
# Обычно [UTM-ссылки](https://tilda.education/articles-how-to-use-utm-url) выглядят примерно так:
#
# `https://example.com/test_page/?utm_source=google&utm_medium=cpc&utm_campaign=my_promo`
#
# Сначала указывается адрес страницы, на которую ведёт ссылка:
#
# `https://example.com/test_page/`
#
# Затем после знака `?` через знак `&` перечисляются параметры с присвоенными им значениями:
#
# * `utm_source=google`
#
# * `utm_medium=cpc`
#
# * `utm_campaign=my_promo`
#
# В результате, если по ссылке будет совершён переход, система аналитики поймёт, что он был с источника `google` c типом трафика `cpc` (оплата за клик по рекламе), а сама рекламная кампания называлась `my_promo`.
#
# В отделе трафика karpov.courses пока решили ограничиться тремя параметрами (`utm_source`, `utm_medium` и `utm_campaign`), поэтому **ваш шаблон UTM-ссылки** будет выглядеть так:
#
# `{website_url}/?utm_source={source}&utm_medium={medium}&utm_campaign={campaign}`
#
#
# Коллеги будут передавать параметры в виде словаря следующего вида:
#
# ```python
# {
#     'website': 'karpovcoursestest.ru',
#     'course': 'newcourse',
#     'utm_source': 'yandex',
#     'utm_medium': 'cpc',
#     'utm_campaign': 'test_promo'
# }
# ```
#
#
# В этом словаре будут указаны три параметра (`utm_source`, `utm_medium` и `utm_campaign`). Также в нём будут указаны название сайта (`website`) и название курса (`course`), из которых нужно составить адрес страницы (`website_url`). По ключам в словаре могут быть указаны любые значения, но сами ключи всегда будут в словаре.
#
# Напишите функцию `utm_builder`, которая будет принимать на вход один аргумент — **словарь с параметрами для UTM-ссылки**. Функция должна вернуть UTM-ссылку, составленную по указанному выше шаблону.
#
# Также функция должна учитывать, что коллеги могут ошибиться и указать значение параметров с заглавными буквами или с лишними пробелами слева или справа, поэтому перед составлением ссылки функция должна дополнительно приводить значения параметров к нижнему регистру и убирать лишние пробелы.
#
# Если какой-то из параметров окажется незаполненным и вместо нормального значения будет указана пустая строка (`''`), функция не должна конструировать и возвращать ссылку, а должна сообщить, у каких параметров (ключей словаря) не указано значение, и вывести в печать сообщение следующего формата:
#
# ```Ошибка. Не переданы параметры: <пропущенные_параметры_через_запятую>.```
#
# При этом отсутствующие параметры должны быть перечислены в порядке их указания в словаре.
#
# **Пример:**
#
# Допустим, на вход в функцию подаётся словарь с параметрами:
#
# ```python
# {
#     'website': 'karpovcoursestest.ru',
#     'course': ' StartDA',
#     'utm_source': 'Yandex',
#     'utm_medium': 'cpc',
#     'utm_campaign': 'test_promo_New_Year '
# }
# ```
#
# Тогда функция должна вернуть следующую UTM-ссылку:
#
# `https://karpovcoursestest.ru/startda/?utm_source=yandex&utm_medium=cpc&utm_campaign=test_promo_new_year`
#
# Если бы вместо значения `'Yandex'` у параметра `utm_source` было указано значение `''` (пустая строка), то функция напечатала бы следующее сообщение:
#
# `Ошибка. Не переданы параметры: utm_source.`
#
# Если бы пустая строка была указана и у параметра `utm_medium`, то функция напечатала бы следующее сообщение:
#
# `Ошибка. Не переданы параметры: utm_source, utm_medium.`
#
# **Примечание:**
#
# Обратите внимание, что в этой задаче в зависимости от ситуации функция должна либо возращать строку с UTM-ссылкой, либо печатать сообщение в требуемом формате.
#
# Почитать, зачем нужны UTM-ссылки, можно [по ссылке](https://tilda.education/articles-how-to-use-utm-url).
#
# Ознакомиться с шаблоном UTM-ссылок можно [тут](https://tilda.cc/ru/utm/).

# %% [markdown]
# <details>
# <summary>&#9658; Нажмите сюда, чтобы увидеть подсказку</summary>
#   <p>
#
# Объявите функцию `utm_builder`, которая в качестве аргумента принимает словарь, содержащий параметры для построения UTM-ссылок.
#
# Для начала необходимо проверить, есть ли в переданном словаре неуказанные параметры, т.е. ключи, значениями по которым являются пустые строки (`''`).
#
# Для этого создайте пустой список, в который будете складывать названия этих параметров (ключи словаря).
#
# С помощью цикла `for` пройдитесь по каждому параметру (ключу) в переданном словаре и с помощью условного оператора `if` проверьте, равно ли значение параметра пустой строке. Если в значении по ключу словаря указана пуcтая строка (`''`), добавьте этот ключ в созданный список.
#
# Далее с помощью `if` проверьте, оказались ли в созданном списке какие-либо ключи (сравните длину списка с 0). Если список не пустой, с помощью метода `join()` объедините элементы списка (ключи с пропущенными значениями) в строку с разделителем `', '` и с помощью функции `print()` и `f-строк` напечатайте сообщение:
#
# ```Ошибка. Не переданы параметры: <пропущенные_параметры_через_запятую>.```
#
# На месте `<пропущенные_параметры_через_запятую>` укажите строку с объединенными параметрами. Затем сразу же завершите работу функции с помощью ключевого слова `return`.
#
#
# Теперь необходимо написать код, который будет конструировать UTM-ссылку, когда переданы все параметры и проверка на отсутствие пустых строк пройдена.
#
# Напишите второй цикл `for`, который будет так же итерироваться по каждому параметру (ключу) в переданном словаре и проводить преобразование значений: убирать пробелы справа и слева от строки с помощью метода `strip()` и приводить все значения к нижнему регистру с помощью метода `lower()`.
#
# В этой части функции вы можете пойти двумя путями: либо перезаписать значения по ключам в текущем словаре с параметрами, либо создать новый словарь и поместить преобразованные значения в него. Допускаются оба варианта.
#
# Теперь, когда у нас есть словарь с исправленными значениями параметров (допустим, он называется `utm_params`), можно приступать к формированию UTM-ссылок:
#
# 1. С помощью `f-строки` объедините в одну строку значения параметров по ключам `'website'` и `'course'` в словаре. Запишите полученную строку в переменную `website_url`, она и будет адресом страницы:
#
# ```python
# website = utm_params['website']
# course = utm_params['course']
# website_url = f'https://{website}/{course}/'
# ```
#
# 2. Так же с помощью `f-строки` объедините в одну строку `website_url` и значения параметров по ключам `'utm_source'`, `'utm_medium'` и `'utm_campaign'` из словаря. Создайте ещё одну переменную (например, `utm_string`) и запишите в неё полученную строку. Эта строка и будет UTM-ссылкой, которую должна вернуть функция:
#
# ```python
# source = utm_params['utm_source']
# medium = utm_params['utm_medium']
# campaign = utm_params['utm_campaign']
#
# utm_string = website_url + f'?utm_source={source}&utm_medium={medium}&utm_campaign={campaign}'
# ```
#
# Ссылка на сайт готова! С помощью ключевого слова `return` верните переменную `utm_string`.
#
#
# </p>
# </details>

# %%
# Ваш код здесь

data = {
    'website': 'kaRpovcoUrsestest.ru',
    'course': ' StartDA',
    'utm_source': 'Yandex',
    'utm_medium': 'cpc',
    'utm_campaign': 'test_promo_New_Year '
}

# %%
l = []
for el in data.items():
    if el[1] == '':
        l.append(el[0])
print(l)
# Out:
# []

# %%
def utm_builder(dict_data):
    l = [] # список ключей словаря, значения которых - пустая строка
    s = '' # строка, в которую складываются ключи со значениями пустых строк
    for el in dict_data.items():
        if el[1] == '':
            l.append(el[0])
                
        if len(l) > 0:
            s = (', ').join(l)
    if s:
        print(f'Ошибка. Не переданы параметры: {s}.')
        return
    else:        
        website_url = dict_data['website']
        website_url = website_url.strip().lower()
        course = dict_data['course']
        course = course.strip().lower()
        source = dict_data['utm_source']
        source = source.strip().lower()
        medium = dict_data['utm_medium']
        medium = medium.strip().lower()
        campaign = dict_data['utm_campaign']
        campaign = campaign.strip().lower()
        pams_list = [website_url, source, medium, campaign]   
        
    return f'{website_url}/{course}/?utm_source={source}&utm_medium={medium}&utm_campaign={campaign}'
        
utm_builder(data)
# Out:
# 'karpovcoursestest.ru/startda/?utm_source=yandex&utm_medium=cpc&utm_campaign=test_promo_new_year'

# %% [markdown]
# ## Итоги

# %% [markdown]
# В этом уроке вы поработали со встроенным интерфейсом Python для работы с файлами, с пользовательскими функциями и генераторами, написали свои первые функции с простыми и сложными структурами кода, освежили знания по работе с условными конструкциями, циклами и структурами данных, а также потренировали следующие навыки:
#
# - Использование конструкции `with open()` для считывания файлов из директории
# - Составление функций с именованными и неименованными аргументами
# - Использование ключевого слова `return` в функциях
# - Создание различных функций в зависимости от необходимого результата и типа передаваемых данных
# - Написание `lambda-функций` и `функций-генераторов`
# - Использование встроенных функций `map()`, `filter()`, `sorted()`
